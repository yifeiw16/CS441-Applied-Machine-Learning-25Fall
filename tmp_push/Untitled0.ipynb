# %%
# !git config --global user.name "yifeiw16"
# !git config --global user.email "yifeiw16@illinois.edu"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/CS441/hw1
# Out:
# /content/drive/MyDrive/CS441/hw1

# %%
# !git init
# !git add .
# !git commit -m "Initial commit from Colab hw1"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/CS441/hw1/.git/
# error: open("Copy of CS441 - HW1  - Report Template.gdoc"): Operation not supported
# error: unable to index file 'Copy of CS441 - HW1  - Report Template.gdoc'
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	CS441_HW1_Starter_yifei_20250902.ipynb
# 	CS441_HW1_Starter_yifei_20250902.pdf
# ...

# %%
# !git add CS441_HW1_Starter_yifei_20250902.ipynb CS441_HW1_Starter_yifei_20250902.pdf temperature_data.npz
# !git commit -m "Initial commit without gdoc file"
# Out:
# [master (root-commit) 172f832] Initial commit without gdoc file
#  3 files changed, 1 insertion(+)
#  create mode 100644 CS441_HW1_Starter_yifei_20250902.ipynb
#  create mode 100644 CS441_HW1_Starter_yifei_20250902.pdf
#  create mode 100644 temperature_data.npz

# %%
# !git branch -M main

# %%
# !git remote add origin https://yifeiw16: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@github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.42 MiB | 2.38 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %cd /content/drive/MyDrive/CS441/hw2
# Out:
# /content/drive/MyDrive/CS441/hw2

# %%
# !echo "*.gdoc" >> .gitignore
# !git add .gitignore

# %%
# !git init
# !git add .
# !git commit -m "Initial commit from Colab hw2"
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/CS441/hw2/.git/
# [main (root-commit) 4049268] Initial commit from Colab hw2
#  3 files changed, 2 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 CS441_HW2_Starter.ipynb
#  create mode 100644 CS441_HW2_Starter.pdf

# %%
# !git branch -M main

# %%
# !git remote add origin https://yifeiw16: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@github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git
# Out:
# error: remote origin already exists.

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 4 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 1.42 MiB | 2.89 MiB/s, done.
# From https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall
#  * [new branch]      main       -> origin/main
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> main

# %%
# !git push -u origin main
# Out:
# To https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git pull origin main --allow-unrelated-histories
# !git push origin main
# Out:
# From https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall
#  * branch            main       -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.
# To https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git
#  ! [rejected]        main -> main (non-fast-forward)
# ...

# %%
# %cd /content/drive/MyDrive/CS441/hw2

# 告诉 git：pull 时采用 merge 策略
# !git config pull.rebase false

# 拉取远程 main 的内容（允许不同历史）
# !git pull origin main --allow-unrelated-histories

# 推送合并后的版本
# !git push origin main
# Out:
# /content/drive/MyDrive/CS441/hw2
# From https://github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall
#  * branch            main       -> FETCH_HEAD
# <t/drive/MyDrive/CS441/hw2/.git/MERGE_MSG" 6L, 315B▽  Pzz\[0%m           [>cMerge branch 'main' of https://github.com/yifeiw16/CS441-Applied-Machine-Learninng-25Fall# Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...

# %%
# 1️⃣ 进入上一级目录
# %cd /content/drive/MyDrive

# !git init
# !git config --global user.name "yifeiw16"
# !git config --global user.email "yifeiw16@illino"

# 2️⃣ 临时复制 CS441 里的内容到一个新的空目录（比如 tmp_push）
# !mkdir -p tmp_push
# !cp -r CS441/* tmp_push/

# 3️⃣ 进入临时目录
# %cd tmp_push

# 5️⃣ 忽略无效文件类型（比如 .gdoc）
# !echo "*.gdoc" >> .gitignore
# !git add .gitignore

# 6️⃣ 添加所有文件
# !git add .

# 7️⃣ 提交
# !git commit -m "Upload CS441 contents"

# 8️⃣ 改名为 main 分支
# !git branch -M main

# 9️⃣ 连接到你的远程仓库
# !git remote add origin https://yifeiw16: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@github.com/yifeiw16/CS441-Applied-Machine-Learning-25Fall.git

# 🔟 推送
# !git push -u origin main --force
# Out:
# /content/drive/MyDrive
# cp: cannot open 'CS441/hw1/Copy of CS441 - HW1  - Report Template.gdoc' for reading: Operation not supported
# cp: cannot open 'CS441/hw2/Copy of CS441 - HW2 - Report .gdoc' for reading: Operation not supported
# cp: cannot open 'CS441/hw3/CS441-HW3-Report.gdoc' for reading: Operation not supported
# cp: cannot open 'CS441/hw4/Copy of CS441 - HW4  - Report Template.gdoc' for reading: Operation not supported
# cp: cannot open 'CS441/hw5/Copy of CS441 - HW5  - Report Template.gdoc' for reading: Operation not supported
# /content/drive/MyDrive/tmp_push
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# ...
